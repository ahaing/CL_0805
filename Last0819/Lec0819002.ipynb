# %%
import ffn
prices =  ffn.get('aapl,msft', start='2010-01-01')
# let's compare the relative performance of each stock
# we will rebase here to get a common starting point for both securities
ax = prices.rebase().plot(figsize=(10, 5))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
prices
# Out:
#                   aapl        msft
# Date
# 2010-01-04    6.487534   23.522568
# 2010-01-05    6.498749   23.530167
# 2010-01-06    6.395379   23.385767
# 2010-01-07    6.383556   23.142553
# 2010-01-08    6.425997   23.302166
# ...                ...         ...
# 2023-08-14  179.460007  323.355408
# 2023-08-15  177.449997  321.179962
# 2023-08-16  176.570007  320.399994
# 2023-08-17  174.000000  316.880005
# 2023-08-18  174.490005  316.480011
#
# [3430 rows x 2 columns]

# %%
import csv
import pandas as pd

def getStockNames() -> pd.Series:
    with open('codeSearch.csv',encoding='utf-8',newline='') as file:
        next(file)
        csv_reader = csv.reader(file)
        stock_codes = {}
        for item in csv_reader:
            key  =  item[2]
            stock_codes[key] = item[3]
        
    code_series:pd.Series = pd.Series(stock_codes)
    return code_series

getStockNames()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 16
#      13     code_series:pd.Series = pd.Series(stock_codes)
#      14     return code_series
# ---> 16 getStockNames()
#
# Cell In[4], line 5, in getStockNames()
#       4 def getStockNames() -> pd.Series:
# ----> 5     with open('codeSearch.csv',encoding='utf-8',newline='') as file:
#       6         next(file)
#       7         csv_reader = csv.reader(file)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'codeSearch.csv'
