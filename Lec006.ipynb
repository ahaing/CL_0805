# %%
# 範例2 (融合版)抓網站資料應用 pandas 
###

import requests
import pandas as pd

# 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
times = 1
cnames = []
for x in range(times):
    url = 'http://www.richyli.com/name/index.asp'
    r = requests.get(url)
    r.encoding = 'big5'
    
    # 將網頁中的資料以分行的方式存成文字檔
    result = r.text.splitlines()
    
    # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
    char_index = result[114].rfind("、")
    temp = result[114][:char_index]
    
    # 將temp的100筆姓名新增到cnames中
    cnames.append(temp)

# 將每100筆姓名的list加一個「、」，再組合成字串存到my_names中
my_names = "、".join(str(x) for x in cnames)
print(my_names)

###

import requests
def getNames(num):
    times = 1
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    print(type(cnames[0]))
    names = cnames[0].split('、')
    return names[:num]

names = getNames(100)
# Out:
# 張威廷、謝宗儒、林柏名、方怡君、柳筱亨、潘俐雲、吳羿純、周佳蓉、陳子揚、李文欣、曾綺華、劉淑芳、謝依羽、酈威貞、侯建平、鄧姿婷、陳蘭剛、張祐岑、趙家慧、張晉芝、陳淑貞、李妙漢、金青豪、黃志隆、溫紹美、袁明輝、邱方沛、吳淑真、林均丹、謝欣妤、李依美、鄧智仁、林佩儒、楊冠良、賴怡昀、林佩祥、袁善佐、黃志鴻、方怡君、李剛以、林則光、郭怡婷、王坤揚、李民青、李盈甄、朱有勇、陳俊臻、林育紹、彭佩儒、溫筱芸、陳姵松、張侑財、謝詩涵、李建貴、王思婷、謝美惠、林育娥、曾欣怡、許偉銘、馮璇豐、陳瓊茹、陳郁廷、李雅晴、游敬駿、林家榮、胡淑娟、胡怡芬、蔡孟哲、游揚綠、蔡琳桓、李劭以、黃志文、連雯嬌、連光鴻、李明夫、黃苡玉、林雅文、陳秀琳、簡淑玲、施翔筠、王婉君、陳采儀、吳鳳南、吳成韋、柳行蕙、鄭秋燕、林仲陽、陳淑真、黃欣儀、楊智超、林庭城、奚丞隆、賴卉青、張淑君、黃建純、鄭雅念、蔣良元、謝亮雯、王苡瑩、權宜靜
# <class 'str'>

# %%
##-1

import numpy as np
import pandas as pd

n2 = np.random.randint(59,100,size=(11,5))
dataFrame = pd.DataFrame(data=n2,
             index=names[:11],
             columns=["國文","英文","數學","地理","歷史"]
             )
dataFrame
# Out:
#      國文  英文  數學  地理  歷史
# 王建臻  92  73  79  94  89
# 林孟容  90  63  63  63  92
# 方筱雯  64  82  87  78  85
# 吳雅惠  93  75  72  95  90
# 黃璇隆  59  62  90  73  89
# 童又謙  60  85  60  86  65
# 楊鎮福  72  71  77  79  97
# 林冠琬  82  97  67  65  81
# 劉政能  83  98  78  68  98
# 許展昇  83  84  65  73  75
# 何筱涵  99  88  64  86  59

# %%
total = dataFrame["數學"]+ dataFrame["地理"]+ dataFrame["歷史"]+ dataFrame["英文"]+ dataFrame["國文"]
dataFrame["TOTAL"] = total
dataFrame
# Out:
#      國文  英文  數學  地理  歷史  TOTAL
# 王建臻  92  73  79  94  89    427
# 林孟容  90  63  63  63  92    371
# 方筱雯  64  82  87  78  85    396
# 吳雅惠  93  75  72  95  90    425
# 黃璇隆  59  62  90  73  89    373
# 童又謙  60  85  60  86  65    356
# 楊鎮福  72  71  77  79  97    396
# 林冠琬  82  97  67  65  81    392
# 劉政能  83  98  78  68  98    425
# 許展昇  83  84  65  73  75    380
# 何筱涵  99  88  64  86  59    396

# %%
# 範例2 v2 => ????
###

import requests
import pandas as pd

def getName():
    # 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
    times = 3
    cnames = []

    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        result = r.text.splitlines()
        
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        cnames.append(temp)
    return cnames
     
names = getNames(3)

# %%
# 範例2 v3 ===> ??? times & getNames(3) 需要解惑
###
import requests
def getNames():
    times = 3
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)    
    return cnames


names = getNames()

# %%
#使用"、"符號,連結3個陣列元素
names_str = "、".join(names)
names_list = names_str.split("、") #有299筆的list
newLine_name = "\n".join(names_list)  #有換行符號的字串
print(newLine_name)
# Out:
# 呂杰齊
# 陳勝誠
# 管丹書
# 趙建文
# 陳致雲
# 溥建安
# 陸萬皓
# 陳宜年
# 蔡雲紋
# 黃柔蕙
# 林昱男
# 吳家惠
# 阮惠雯
# 陳靖松
# 陳淑娟
# 彭愛汝
# 張憲仰
# 林怡伶
# 陳玟君
# 鄭揚琬
# 林琳忠
# 楊素勇
# 張明翰
# 蔡左鳳
# 謝政宏
# 吳倫榮
# 黃聖傑
# 劉文婷
# 錢怡伶
# 黃玄年
# 陳于真
# 陳麗任
# 李姿妤
# 陳冠瑄
# 沈胤平
# 李萱馨
# 吳淑娟
# 林世茵
# 張韋伶
# 周安皓
# 林依婷
# 陳信以
# 黃麗斌
# 楊杰娥
# 王聖其
# 李柏桂
# 張景易
# 黃子柏
# 王思宸
# 賴先宜
# 葉曉白
# 陳淑生
# 鄭哲維
# 李彥勇
# 姚子傑
# 陳馨慧
# 黃建宏
# 王瑜添
# 吳雅玲
# 焦琬為
# 馬志平
# 慕俊賢
# 彭彥廷
# 王俊航
# 倪均心
# 陳秉雨
# 潘詩菱
# 蔡韻如
# 陳喬鴻
# 顏子杰
# 韓貞剛
# 陳怡珊
# 高幸意
# 吳苡珍
# 張淑敏
# 曾千穎
# 陳政達
# 鄂琦瑩
# 黃郁帆
# 鐘宗翰
# 李秀新
# 毛明和
# 朱仰斌
# 陳慧傑
# 陳俊姍
# 郭雅恩
# 林慧娟
# 張家銘
# 張胤伸
# 吳萱花
# 李美利
# 黃靜宜
# 李茜然
# 洪淑玲
# 黃任財
# 洪乃文
# 周炳威
# 王莉齊
# 蘇儒和
# 朱鳳珠
# 陳宥凱
# 簡惠婷
# 彭宛玲
# 武雅晴
# 李美娟
# 賀雅君
# 韓語政
# 廖偉迪
# 吳秉和
# 盧岳瑩
# 劉志成
# 陳怡靜
# 陳文勇
# 魏麗娟
# 鄭舜文
# 陳新珮
# 鄭淑惠
# 張惟斌
# 吳國華
# 童力卉
# 賴宜芳
# 林柏毅
# 李靜如
# 劉怡勇
# 鄭仁妮
# 陳喜紹
# 袁依婷
# 江志賢
# 李潔銘
# 蔡志翔
# 劉佳芳
# 馬琇舜
# 林詠虹
# 陳柏利
# 邱宛儒
# 陳怡忠
# 張文季
# 黃啟山
# 錢佩玲
# 鄭宇達
# 林家啟
# 林智傑
# 秦凱鈞
# 田毅嘉
# 張毓希
# 經京銘
# 黃華仁
# 林韋海
# 黃俊明
# 李嘉淳
# 楊慈喜
# 高倩美
# 白林齊
# 葉中妏
# 韓慧君
# 鬱國鳳
# 金淑君
# 劉建宇
# 謝倍妏
# 李政江
# 吳秋芝
# 陳家銘
# 李剛如
# 陳靜綸
# 黃蘭瑩
# 鄧宏達
# 黃莉月
# 謝木一
# 李秀喜
# 劉淑敏
# 張曜宇
# 陳雅凡
# 沈瑋倫
# 淩俐潔
# 童曼華
# 黃莉青
# 黃淑媛
# 吳珮君
# 許政旭
# 林肇隆
# 鄭佳蓉
# 洪國珠
# 黃揚佳
# 黎靜如
# 林欣仲
# 李建安
# 吳士哲
# 李雅惠
# 吳柏軍
# 林雅玲
# 李宜全
# 邱淑珍
# 陳映志
# 林彥吟
# 黃建筠
# 洪貞儀
# 陳詩為
# 周怡娥
# 廖偉諭
# 張家旺
# 林秀珍
# 陳怡靜
# 洪火原
# 黃沛民
# 許惠珠
# 李怡中
# 張柏廷
# 周佳蓉
# 黃怡美
# 林政哲
# 楊毅筠
# 徐晴淑
# 張凱仁
# 張憲法
# 秦依婷
# 李惠珍
# 陳建智
# 林筱盈
# 林孟彥
# 胡婷婷
# 鄭佩璇
# 許俊彥
# 杜允軒
# 吳佳筠
# 蔡惠珠
# 陳琪華
# 鞠守憲
# 張惠君
# 馬聿枝
# 鄭雅馨
# 陳芝良
# 阮麗雯
# 黃信旭
# 林婉任
# 彭茜柔
# 吳喜典
# 宋佳蓉
# 黃怡潔
# 陳佳強
# 蔡紹文
# 陳淑慈
# 李惠婷
# 駱伯源
# 林佩財
# 游文馨
# 陳宣傑
# 蘇麗美
# 王牧添
# 吳依婷
# 黃仁豪
# 劉怡依
# 陳玉玲
# 陳政淳
# 涂佩怡
# 江曼心
# 陳虹其
# 許婉如
# 黃偉中
# 陳佳穎
# 吳偉倫
# 夏剛春
# 黃季夢
# 姚思婷
# 吳文馨
# 邱勝意
# 方妙亮
# 蒙玟君
# 王家瑋
# 陳俊維
# 孫志銘
# 夏喬全
# 謝東茵
# 劉欣元
# 孫如君
# 劉俊諺
# 謝雪群
# 陳玉梅
# 王倩卿
# 盧佳宏
# 魏又昌
# 鍾明年
# 吳玟君
# 吳羿雅
# 陳秀芬
# 楊冠伶
# 李振州
# 邱穎孝
# 王昕恬
# 張憶宏
# 吳秋正
# 王寶映
# 陳志發
# 劉家群
# 陳婉筠
# 王信宏
# 林韻玄
# 吳玉華
# 王允瑄
# 黃冠綸
# 李佳蓉

# %%
with open("names.csv",mode="w",encoding='utf-8',newline="") as file:
    file.write(newLine_name)
